# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavimidde/Deep_learning/blob/main/DLLAB7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()

model.add(Conv2D(6, kernel_size=(5,5), activation='tanh', input_shape=(32,32,3)))
model.add(AveragePooling2D((2,2)))

model.add(Conv2D(16, kernel_size=(5,5), activation='tanh'))
model.add(AveragePooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120, activation='tanh'))
model.add(Dense(84, activation='tanh'))
model.add(Dense(100, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(x_train_main, y_train_main,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │         8,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,656 (272.09 KB)
#  Trainable params: 69,656 (272.09 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.0876 - loss: 4.0732 - val_accuracy: 0.1313 - val_loss: 3.8103
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1503 - loss: 3.6952 - val_accuracy: 0.1634 - val_loss: 3.6428
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1756 - loss: 3.5371 - val_accuracy: 0.1759 - val_loss: 3.5278
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1953 - loss: 3.4225 - val_accuracy: 0.1903 - val_loss: 3.4491
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2092 - loss: 3.3316 - val_accuracy: 0.1995 - val_loss: 3.3960
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2253 - loss: 3.2514 - val_accuracy: 0.2001 - val_loss: 3.3581
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2339 - loss: 3.1876 - val_accuracy: 0.2094 - val_loss: 3.3386
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2424 - loss: 3.1315 - val_accuracy: 0.2196 - val_loss: 3.2836
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2533 - loss: 3.0766 - val_accuracy: 0.2194 - val_loss: 3.2662
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2616 - loss: 3.0305 - val_accuracy: 0.2270 - val_loss: 3.2418
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2686 - loss: 2.9821 - val_accuracy: 0.2209 - val_loss: 3.2328
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2759 - loss: 2.9463 - val_accuracy: 0.2282 - val_loss: 3.2138
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2841 - loss: 2.9041 - val_accuracy: 0.2320 - val_loss: 3.2065
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2900 - loss: 2.8703 - val_accuracy: 0.2364 - val_loss: 3.1988
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2991 - loss: 2.8295 - val_accuracy: 0.2350 - val_loss: 3.2023
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3019 - loss: 2.8011 - val_accuracy: 0.2348 - val_loss: 3.1950
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3084 - loss: 2.7708 - val_accuracy: 0.2352 - val_loss: 3.1973
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3150 - loss: 2.7367 - val_accuracy: 0.2396 - val_loss: 3.1993
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3237 - loss: 2.7069 - val_accuracy: 0.2428 - val_loss: 3.1953
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3255 - loss: 2.6772 - val_accuracy: 0.2407 - val_loss: 3.1983
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2473 - loss: 3.1899
# Test accuracy: 0.24729999899864197

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()

model.add(Conv2D(6, kernel_size=(5,5), activation='relu', input_shape=(32,32,3)))
model.add(AveragePooling2D((2,2)))

model.add(Conv2D(16, kernel_size=(5,5), activation='relu'))
model.add(AveragePooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(100, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(x_train_main, y_train_main,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 100)            │         8,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,656 (272.09 KB)
#  Trainable params: 69,656 (272.09 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0542 - loss: 4.2322 - val_accuracy: 0.0846 - val_loss: 3.9947
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1236 - loss: 3.7919 - val_accuracy: 0.1365 - val_loss: 3.7236
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1645 - loss: 3.5289 - val_accuracy: 0.1711 - val_loss: 3.4852
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1954 - loss: 3.3556 - val_accuracy: 0.1968 - val_loss: 3.3672
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2159 - loss: 3.2420 - val_accuracy: 0.2042 - val_loss: 3.3104
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2348 - loss: 3.1561 - val_accuracy: 0.2269 - val_loss: 3.2088
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2473 - loss: 3.0842 - val_accuracy: 0.2309 - val_loss: 3.1726
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2587 - loss: 3.0185 - val_accuracy: 0.2232 - val_loss: 3.1834
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2673 - loss: 2.9730 - val_accuracy: 0.2428 - val_loss: 3.1492
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2793 - loss: 2.9177 - val_accuracy: 0.2491 - val_loss: 3.0799
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2858 - loss: 2.8834 - val_accuracy: 0.2498 - val_loss: 3.0948
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2925 - loss: 2.8454 - val_accuracy: 0.2540 - val_loss: 3.0634
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3022 - loss: 2.8029 - val_accuracy: 0.2568 - val_loss: 3.0785
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3079 - loss: 2.7684 - val_accuracy: 0.2670 - val_loss: 3.0275
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3140 - loss: 2.7353 - val_accuracy: 0.2610 - val_loss: 3.0557
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3198 - loss: 2.7033 - val_accuracy: 0.2705 - val_loss: 2.9985
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3269 - loss: 2.6764 - val_accuracy: 0.2651 - val_loss: 3.0332
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3319 - loss: 2.6481 - val_accuracy: 0.2761 - val_loss: 3.0114
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3386 - loss: 2.6217 - val_accuracy: 0.2714 - val_loss: 3.0136
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3431 - loss: 2.5974 - val_accuracy: 0.2666 - val_loss: 3.0460
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2715 - loss: 3.0208
# Test accuracy: 0.27149999141693115

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()

model.add(Conv2D(6, kernel_size=(5,5), activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(16, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(100, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(x_train_main, y_train_main,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 100)            │         8,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,656 (272.09 KB)
#  Trainable params: 69,656 (272.09 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.0608 - loss: 4.2025 - val_accuracy: 0.1040 - val_loss: 3.9286
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1333 - loss: 3.7349 - val_accuracy: 0.1551 - val_loss: 3.6135
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1800 - loss: 3.4774 - val_accuracy: 0.1814 - val_loss: 3.4461
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2118 - loss: 3.2952 - val_accuracy: 0.2094 - val_loss: 3.2971
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2343 - loss: 3.1564 - val_accuracy: 0.2172 - val_loss: 3.2490
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2548 - loss: 3.0513 - val_accuracy: 0.2391 - val_loss: 3.1537
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2696 - loss: 2.9677 - val_accuracy: 0.2465 - val_loss: 3.0970
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2831 - loss: 2.9038 - val_accuracy: 0.2559 - val_loss: 3.0631
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2957 - loss: 2.8380 - val_accuracy: 0.2649 - val_loss: 3.0242
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3049 - loss: 2.7823 - val_accuracy: 0.2729 - val_loss: 2.9888
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3143 - loss: 2.7409 - val_accuracy: 0.2730 - val_loss: 2.9964
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3243 - loss: 2.6899 - val_accuracy: 0.2800 - val_loss: 2.9691
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3345 - loss: 2.6450 - val_accuracy: 0.2806 - val_loss: 2.9725
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3409 - loss: 2.6103 - val_accuracy: 0.2833 - val_loss: 2.9464
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3471 - loss: 2.5752 - val_accuracy: 0.2891 - val_loss: 2.9301
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3523 - loss: 2.5460 - val_accuracy: 0.2896 - val_loss: 2.9135
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3575 - loss: 2.5108 - val_accuracy: 0.2962 - val_loss: 2.9016
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3672 - loss: 2.4767 - val_accuracy: 0.2890 - val_loss: 2.9469
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3724 - loss: 2.4497 - val_accuracy: 0.2968 - val_loss: 2.9085
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3766 - loss: 2.4193 - val_accuracy: 0.2989 - val_loss: 2.9153
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2974 - loss: 2.8965
# Test accuracy: 0.29739999771118164

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(100, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main,
          epochs=25,
          batch_size=128,
          validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.0269 - loss: 4.4327 - val_accuracy: 0.0781 - val_loss: 4.1232
# Epoch 2/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0750 - loss: 4.0148 - val_accuracy: 0.1330 - val_loss: 3.6946
# Epoch 3/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1182 - loss: 3.7453 - val_accuracy: 0.1786 - val_loss: 3.4437
# Epoch 4/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1450 - loss: 3.5690 - val_accuracy: 0.2137 - val_loss: 3.3192
# Epoch 5/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1673 - loss: 3.4380 - val_accuracy: 0.2296 - val_loss: 3.1605
# Epoch 6/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1868 - loss: 3.3378 - val_accuracy: 0.2432 - val_loss: 3.1145
# Epoch 7/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1997 - loss: 3.2592 - val_accuracy: 0.2663 - val_loss: 2.9989
# Epoch 8/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2182 - loss: 3.1712 - val_accuracy: 0.2661 - val_loss: 2.9744
# Epoch 9/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2285 - loss: 3.1153 - val_accuracy: 0.2781 - val_loss: 2.9222
# Epoch 10/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2434 - loss: 3.0425 - val_accuracy: 0.2894 - val_loss: 2.8580
# Epoch 11/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2499 - loss: 2.9894 - val_accuracy: 0.2884 - val_loss: 2.8607
# Epoch 12/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2610 - loss: 2.9357 - val_accuracy: 0.3043 - val_loss: 2.8199
# Epoch 13/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2706 - loss: 2.8783 - val_accuracy: 0.3126 - val_loss: 2.7509
# Epoch 14/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2775 - loss: 2.8430 - val_accuracy: 0.3167 - val_loss: 2.7450
# Epoch 15/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2868 - loss: 2.7947 - val_accuracy: 0.3164 - val_loss: 2.7300
# Epoch 16/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2919 - loss: 2.7572 - val_accuracy: 0.3249 - val_loss: 2.7038
# Epoch 17/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2979 - loss: 2.7277 - val_accuracy: 0.3315 - val_loss: 2.6894
# Epoch 18/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3055 - loss: 2.6838 - val_accuracy: 0.3357 - val_loss: 2.6787
# Epoch 19/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3150 - loss: 2.6531 - val_accuracy: 0.3367 - val_loss: 2.6549
# Epoch 20/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3146 - loss: 2.6255 - val_accuracy: 0.3386 - val_loss: 2.6499
# Epoch 21/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3221 - loss: 2.5917 - val_accuracy: 0.3467 - val_loss: 2.6280
# Epoch 22/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3287 - loss: 2.5558 - val_accuracy: 0.3433 - val_loss: 2.6300
# Epoch 23/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3331 - loss: 2.5309 - val_accuracy: 0.3376 - val_loss: 2.6290
# Epoch 24/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3347 - loss: 2.5115 - val_accuracy: 0.3439 - val_loss: 2.6193
# Epoch 25/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3420 - loss: 2.4779 - val_accuracy: 0.3418 - val_loss: 2.6462
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3399 - loss: 2.6248
# Test accuracy: 0.3398999869823456

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))

model.add(Dense(100, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

model.fit(
    x_train_main, y_train_main,
    epochs=30,
    batch_size=128,
    validation_data=(x_val, y_val)
)

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.0202 - loss: 4.5173 - val_accuracy: 0.0294 - val_loss: 4.3577
# Epoch 2/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0405 - loss: 4.2841 - val_accuracy: 0.0726 - val_loss: 4.1592
# Epoch 3/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0709 - loss: 4.1046 - val_accuracy: 0.0998 - val_loss: 3.9862
# Epoch 4/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.0983 - loss: 3.9516 - val_accuracy: 0.1191 - val_loss: 3.8339
# Epoch 5/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1143 - loss: 3.8284 - val_accuracy: 0.1337 - val_loss: 3.7405
# Epoch 6/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1247 - loss: 3.7454 - val_accuracy: 0.1442 - val_loss: 3.6602
# Epoch 7/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1364 - loss: 3.6782 - val_accuracy: 0.1511 - val_loss: 3.6079
# Epoch 8/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1455 - loss: 3.6159 - val_accuracy: 0.1641 - val_loss: 3.5565
# Epoch 9/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1550 - loss: 3.5623 - val_accuracy: 0.1713 - val_loss: 3.4949
# Epoch 10/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1637 - loss: 3.5169 - val_accuracy: 0.1798 - val_loss: 3.4467
# Epoch 11/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1713 - loss: 3.4682 - val_accuracy: 0.1842 - val_loss: 3.4102
# Epoch 12/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1796 - loss: 3.4273 - val_accuracy: 0.1929 - val_loss: 3.3820
# Epoch 13/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1852 - loss: 3.3895 - val_accuracy: 0.1995 - val_loss: 3.3380
# Epoch 14/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1948 - loss: 3.3467 - val_accuracy: 0.2070 - val_loss: 3.2991
# Epoch 15/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1989 - loss: 3.3124 - val_accuracy: 0.2112 - val_loss: 3.2700
# Epoch 16/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2074 - loss: 3.2752 - val_accuracy: 0.2197 - val_loss: 3.2247
# Epoch 17/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2117 - loss: 3.2437 - val_accuracy: 0.2248 - val_loss: 3.1967
# Epoch 18/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2164 - loss: 3.2171 - val_accuracy: 0.2323 - val_loss: 3.1706
# Epoch 19/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2220 - loss: 3.1897 - val_accuracy: 0.2347 - val_loss: 3.1535
# Epoch 20/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2260 - loss: 3.1603 - val_accuracy: 0.2436 - val_loss: 3.1263
# Epoch 21/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2317 - loss: 3.1319 - val_accuracy: 0.2435 - val_loss: 3.1039
# Epoch 22/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2383 - loss: 3.1070 - val_accuracy: 0.2481 - val_loss: 3.0843
# Epoch 23/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2418 - loss: 3.0846 - val_accuracy: 0.2476 - val_loss: 3.0773
# Epoch 24/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2474 - loss: 3.0603 - val_accuracy: 0.2534 - val_loss: 3.0405
# Epoch 25/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2504 - loss: 3.0385 - val_accuracy: 0.2612 - val_loss: 3.0322
# Epoch 26/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2561 - loss: 3.0185 - val_accuracy: 0.2567 - val_loss: 3.0312
# Epoch 27/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2595 - loss: 2.9943 - val_accuracy: 0.2659 - val_loss: 2.9888
# Epoch 28/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2627 - loss: 2.9782 - val_accuracy: 0.2703 - val_loss: 2.9756
# Epoch 29/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2654 - loss: 2.9605 - val_accuracy: 0.2715 - val_loss: 2.9634
# Epoch 30/30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2706 - loss: 2.9391 - val_accuracy: 0.2734 - val_loss: 2.9506
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2850 - loss: 2.9349
# Test accuracy: 0.2849999964237213

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator


(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2076 - loss: 3.2680 - val_accuracy: 0.2495 - val_loss: 3.0577
# Epoch 26/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.2114 - loss: 3.2539 - val_accuracy: 0.2518 - val_loss: 3.0287
# Epoch 27/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.2137 - loss: 3.2345 - val_accuracy: 0.2670 - val_loss: 2.9750
# Epoch 28/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2144 - loss: 3.2105 - val_accuracy: 0.2683 - val_loss: 2.9570
# Epoch 29/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2199 - loss: 3.2049 - val_accuracy: 0.2625 - val_loss: 2.9764
# Epoch 30/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2205 - loss: 3.1807 - val_accuracy: 0.2679 - val_loss: 2.9565
# Epoch 31/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.2256 - loss: 3.1632 - val_accuracy: 0.2760 - val_loss: 2.9120
# Epoch 32/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.2310 - loss: 3.1415 - val_accuracy: 0.2767 - val_loss: 2.9021
# Epoch 33/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.2304 - loss: 3.1319 - val_accuracy: 0.2759 - val_loss: 2.9179
# Epoch 34/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2346 - loss: 3.1134 - val_accuracy: 0.2848 - val_loss: 2.8715
# Epoch 35/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2351 - loss: 3.1075 - val_accuracy: 0.2839 - val_loss: 2.8493
# Epoch 36/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.2377 - loss: 3.0870 - val_accuracy: 0.2822 - val_loss: 2.8781
# Epoch 37/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2436 - loss: 3.0680 - val_accuracy: 0.2920 - val_loss: 2.8327
# Epoch 38/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2455 - loss: 3.0580 - val_accuracy: 0.2825 - val_loss: 2.8594
# Epoch 39/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2443 - loss: 3.0591 - val_accuracy: 0.2924 - val_loss: 2.8224
# Epoch 40/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.2465 - loss: 3.0423 - val_accuracy: 0.2767 - val_loss: 2.8994
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2877 - loss: 2.8798
# Test accuracy: 0.28769999742507935

# %% [markdown]
# Among all the above code i got better if the le-net uses maxPooling and relu activation function

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

# Train-validation split
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Normalize
x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(x_train_main)

# Model
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))

model.add(Dense(100, activation='softmax'))

# Compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# Train
model.fit(
    datagen.flow(x_train_main, y_train_main, batch_size=128),
    epochs=35,
    validation_data=(x_val, y_val)
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 124ms/step - accuracy: 0.0375 - loss: 4.4689 - val_accuracy: 0.0466 - val_loss: 4.4508
# Epoch 2/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.0818 - loss: 4.1061 - val_accuracy: 0.1222 - val_loss: 3.9105
# Epoch 3/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.1133 - loss: 3.8738 - val_accuracy: 0.1482 - val_loss: 3.6968
# Epoch 4/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.1416 - loss: 3.6998 - val_accuracy: 0.1684 - val_loss: 3.5471
# Epoch 5/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.1585 - loss: 3.5718 - val_accuracy: 0.1845 - val_loss: 3.4560
# Epoch 6/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s
35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - accuracy: 0.3549 - loss: 2.5071 - val_accuracy: 0.3682 - val_loss: 2.4957
# Epoch 35/35
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.3595 - loss: 2.4895 - val_accuracy: 0.3725 - val_loss: 2.4607
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3788 - loss: 2.4139
# Test accuracy: 0.37880000472068787

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

# Split
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Normalize
x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# One-hot
y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train_main)

# Model
model = Sequential()

model.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(192, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(384, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(100, activation='softmax'))

# Compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# Train
model.fit(
    datagen.flow(x_train_main, y_train_main, batch_size=128),
    epochs=40,
    validation_data=(x_val, y_val)
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 48s 119ms/step - accuracy: 0.0937 - loss: 4.0056 - val_accuracy: 0.0175 - val_loss: 4.7316
# Epoch 2/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 109ms/step - accuracy: 0.1879 - loss: 3.3653 - val_accuracy: 0.2434 - val_loss: 3.1425
# Epoch 3/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 92ms/step - accuracy: 0.2504 - loss: 3.0183 - val_accuracy: 0.3069 - val_loss: 2.7745
# Epoch 4/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.3015 - loss: 2.7653 - val_accuracy: 0.3419 - val_loss: 2.5902
# Epoch 5/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.3357 - loss: 2.5726 - val_accuracy: 0.3737 - val_loss: 2.4115
# Epoch 6/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.3756 - loss: 2.3980 - val_accuracy: 0.3923 - val_loss: 2.3342
# Epoch 7/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.4038 - loss: 2.2580 - val_accuracy: 0.4048 - val_loss: 2.3038
# Epoch 8/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.4369 - loss: 2.1235 - val_accuracy: 0.4354 - val_loss: 2.1506
# Epoch 9/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.4596 - loss: 2.0081 - val_accuracy: 0.4169 - val_loss: 2.2862
# Epoch 10/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.4813 - loss: 1.9172 - val_accuracy: 0.4432 - val_loss: 2.1530
# Epoch 11/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.5061 - loss: 1.8125 - val_accuracy: 0.4519 - val_loss: 2.1334
# Epoch 12/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.5252 - loss: 1.7313 - val_accuracy: 0.4889 - val_loss: 1.9340
# Epoch 13/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.5463 - loss: 1.6360 - val_accuracy: 0.4812 - val_loss: 2.0067
# Epoch 14/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.5634 - loss: 1.5650 - val_accuracy: 0.4734 - val_loss: 2.0805
# Epoch 15/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.5852 - loss: 1.4803 - val_accuracy: 0.4948 - val_loss: 1.9519
# Epoch 16/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.5982 - loss: 1.4204 - val_accuracy: 0.4943 - val_loss: 2.0183
# Epoch 17/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.6177 - loss: 1.3472 - val_accuracy: 0.5257 - val_loss: 1.8422
# Epoch 18/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6308 - loss: 1.2874 - val_accuracy: 0.5146 - val_loss: 1.9427
# Epoch 19/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6486 - loss: 1.2223 - val_accuracy: 0.5239 - val_loss: 1.9148
# Epoch 20/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6629 - loss: 1.1675 - val_accuracy: 0.5182 - val_loss: 1.9364
# Epoch 21/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6763 - loss: 1.1115 - val_accuracy: 0.5273 - val_loss: 1.8949
# Epoch 22/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.6909 - loss: 1.0526 - val_accuracy: 0.5051 - val_loss: 2.0637
# Epoch 23/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.7058 - loss: 1.0023 - val_accuracy: 0.5287 - val_loss: 1.8927
# Epoch 24/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7180 - loss: 0.9519 - val_accuracy: 0.5234 - val_loss: 1.9224
# Epoch 25/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.7264 - loss: 0.9130 - val_accuracy: 0.5407 - val_loss: 1.9061
# Epoch 26/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.7400 - loss: 0.8687 - val_accuracy: 0.5333 - val_loss: 1.9391
# Epoch 27/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.7500 - loss: 0.8307 - val_accuracy: 0.5237 - val_loss: 1.9946
# Epoch 28/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.7647 - loss: 0.7850 - val_accuracy: 0.5433 - val_loss: 1.8911
# Epoch 29/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.7685 - loss: 0.7658 - val_accuracy: 0.5268 - val_loss: 2.0343
# Epoch 30/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.7779 - loss: 0.7297 - val_accuracy: 0.5476 - val_loss: 1.9138
# Epoch 31/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.7915 - loss: 0.6875 - val_accuracy: 0.5229 - val_loss: 2.0862
# Epoch 32/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - accuracy: 0.7976 - loss: 0.6709 - val_accuracy: 0.5169 - val_loss: 2.1461
# Epoch 33/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.8023 - loss: 0.6406 - val_accuracy: 0.5035 - val_loss: 2.3351
# Epoch 34/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.8122 - loss: 0.6059 - val_accuracy: 0.5257 - val_loss: 2.1222
# Epoch 35/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.8209 - loss: 0.5776 - val_accuracy: 0.5485 - val_loss: 2.0185
# Epoch 36/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.8278 - loss: 0.5623 - val_accuracy: 0.5450 - val_loss: 2.0232
# Epoch 37/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.8332 - loss: 0.5340 - val_accuracy: 0.5318 - val_loss: 2.1991
# Epoch 38/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.8390 - loss: 0.5152 - val_accuracy: 0.5303 - val_loss: 2.1800
# Epoch 39/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.8430 - loss: 0.5051 - val_accuracy: 0.5287 - val_loss: 2.2707
# Epoch 40/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.8495 - loss: 0.4786 - val_accuracy: 0.5488 - val_loss: 2.1276
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5608 - loss: 2.0105
# Test accuracy: 0.5608000159263611

# %% [markdown]
# if i use alex net with maxPooling and relu it got increased.

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

# Split
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Normalize
x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Data Augmentation (VERY IMPORTANT)
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train_main)

# ZFNet Model
model = Sequential()

# Block 1
model.add(Conv2D(96, (3,3), strides=1, padding='same', activation='relu', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Block 2
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Block 3
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

# Fully Connected
model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(100, activation='softmax'))

# Compile
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# Train
model.fit(
    datagen.flow(x_train_main, y_train_main, batch_size=128),
    epochs=50,
    validation_data=(x_val, y_val)
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━
50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.6098 - loss: 1.3837 - val_accuracy: 0.5394 - val_loss: 1.7641
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6160 - loss: 1.3595 - val_accuracy: 0.5381 - val_loss: 1.7977
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6223 - loss: 1.3334 - val_accuracy: 0.5540 - val_loss: 1.7262
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6346 - loss: 1.2913 - val_accuracy: 0.5230 - val_loss: 1.8486
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.6435 - loss: 1.2518 - val_accuracy: 0.5490 - val_loss: 1.7746
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.6488 - loss: 1.2237 - val_accuracy: 0.5467 - val_loss: 1.7883
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6556 - loss: 1.2054 - val_accuracy: 0.5455 - val_loss: 1.7979
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.6643 - loss: 1.1690 - val_accuracy: 0.5543 - val_loss: 1.7543
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6680 - loss: 1.1481 - val_accuracy: 0.5481 - val_loss: 1.7845
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6742 - loss: 1.1261 - val_accuracy: 0.5582 - val_loss: 1.7765
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6851 - loss: 1.0834 - val_accuracy: 0.5425 - val_loss: 1.8709
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.6927 - loss: 1.0606 - val_accuracy: 0.5519 - val_loss: 1.8309
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - accuracy: 0.6928 - loss: 1.0494 - val_accuracy: 0.5336 - val_loss: 1.9498
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.7035 - loss: 1.0217 - val_accuracy: 0.5457 - val_loss: 1.8876
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.7075 - loss: 1.0004 - val_accuracy: 0.5564 - val_loss: 1.8143
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 91ms/step - accuracy: 0.7120 - loss: 0.9757 - val_accuracy: 0.5554 - val_loss: 1.8524
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 91ms/step - accuracy: 0.7214 - loss: 0.9494 - val_accuracy: 0.5582 - val_loss: 1.8225
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.7270 - loss: 0.9318 - val_accuracy: 0.5550 - val_loss: 1.9111
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.7317 - loss: 0.9081 - val_accuracy: 0.5164 - val_loss: 2.1263
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5270 - loss: 2.0543
# Test accuracy: 0.5270000100135803

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# Load dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

# Train-validation split
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Normalize
x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Data Augmentation (IMPROVED)
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    zoom_range=0.1
)

datagen.fit(x_train_main)

# ZFNet Model
model = Sequential()

# Block 1
model.add(Conv2D(96, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Block 2
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Block 3
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

# Fully Connected
model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(100, activation='softmax'))

# Compile (LOWER LR for better learning)
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.00005),
    metrics=['accuracy']
)

# Learning Rate Scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# Train
model.fit(
    datagen.flow(x_train_main, y_train_main, batch_size=128),
    epochs=70,
    validation_data=(x_val, y_val),
    callbacks=[lr_scheduler]
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)

# %%
import keras
from keras import datasets
from keras.models import Model
from keras.layers import Conv2D, BatchNormalization, Activation, Add
from keras.layers import Input, GlobalAveragePooling2D, Dense
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar100.load_data()

# Split
x_train_main = x_train[:40000]
y_train_main = y_train[:40000]
x_val = x_train[40000:]
y_val = y_train[40000:]

# Normalize
x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

# One-hot encoding
y_train_main = to_categorical(y_train_main, 100)
y_val = to_categorical(y_val, 100)
y_test = to_categorical(y_test, 100)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train_main)

# Residual Block
def residual_block(x, filters, downsample=False):
    stride = 2 if downsample else 1

    shortcut = x

    x = Conv2D(filters, (3,3), strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)

    # Adjust shortcut if needed
    if downsample:
        shortcut = Conv2D(filters, (1,1), strides=2, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

# Model
inputs = Input(shape=(32,32,3))

x = Conv2D(64, (3,3), padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# ResNet Blocks
x = residual_block(x, 64)
x = residual_block(x, 64)

x = residual_block(x, 128, downsample=True)
x = residual_block(x, 128)

x = residual_block(x, 256, downsample=True)
x = residual_block(x, 256)

x = residual_block(x, 512, downsample=True)
x = residual_block(x, 512)

# Output
x = GlobalAveragePooling2D()(x)
outputs = Dense(100, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(
    datagen.flow(x_train_main, y_train_main, batch_size=128),
    epochs=50,
    validation_data=(x_val, y_val)
)

# Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 182ms/step - accuracy: 0.1464 - loss: 3.6882 - val_accuracy: 0.0147 - val_loss: 6.0630
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.2491 - loss: 3.0387 - val_accuracy: 0.2464 - val_loss: 3.0830
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.3159 - loss: 2.7028 - val_accuracy: 0.3103 - val_loss: 2.7644
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.3677 - loss: 2.4459 - val_accuracy: 0.3251 - val_loss: 2.6460
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.4148 - loss: 2.2323 - val_accuracy: 0.3699 - val_loss: 2.4892
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.4473 - loss: 2.0704 - val_accuracy: 0.4106 - val_loss: 2.2764
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.4809 - loss: 1.9281 - val_accuracy: 0.3890 - val_loss: 2.4357
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.5111 - loss: 1.7957 - val_accuracy: 0.4237 - val_loss: 2.2331
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.5379 - loss: 1.6893 - val_accuracy: 0.4455 - val_loss: 2.0934
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.5633 - loss: 1.5800 - val_accuracy: 0.4748 - val_loss: 2.0324
# Epoch 11/50
# 246/313 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - accuracy: 0.5957 - loss: 1.4597
