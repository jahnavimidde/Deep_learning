# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavimidde/Deep_learning/blob/main/RNN_DL_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
import numpy as np

# Vocabulary (characters)
vocab = ['d', 'e', 'p', '<stop>']
char2idx = {c: i for i, c in enumerate(vocab)}
idx2char = {i: c for c, i in char2idx.items()}

# Sequence: "dep"
sequence = ['d', 'e', 'p']
target = ['e', 'p', '<stop>']

# One-hot encoding
X = np.eye(len(vocab))[[char2idx[c] for c in sequence]].reshape(len(sequence), 1, len(vocab))
y = np.eye(len(vocab))[[char2idx[c] for c in target]]

# Model
model = Sequential([
    SimpleRNN(8, input_shape=(1, len(vocab))),
    Dense(len(vocab), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=200, verbose=0)

# Predict next char after 'p'
test = np.eye(len(vocab))[char2idx['p']].reshape(1,1,len(vocab))
pred = model.predict(test)
print("Next char:", idx2char[np.argmax(pred)])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Next char: <stop>

# %%
# Vocabulary (words)
vocab = ['deep', 'learning', 'is', '<stop>']
word2idx = {w: i for i, w in enumerate(vocab)}
idx2word = {i: w for w, i in word2idx.items()}

sequence = ['deep', 'learning', 'is']
target = ['learning', 'is', '<stop>']

# One-hot encoding
X = np.eye(len(vocab))[[word2idx[w] for w in sequence]].reshape(len(sequence), 1, len(vocab))
y = np.eye(len(vocab))[[word2idx[w] for w in target]]

# Model
model = Sequential([
    SimpleRNN(8, input_shape=(1, len(vocab))),
    Dense(len(vocab), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=300, verbose=0)

# Predict next word after 'is'
test = np.eye(len(vocab))[word2idx['is']].reshape(1,1,len(vocab))
pred = model.predict(test)
print("Next word:", idx2word[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Next word: <stop>

# %%
# Sentence vocabulary
vocab = [
    'deep learning is fun',
    'machine learning is powerful',
    'AI is the future',
    '<stop>'
]

sent2idx = {s: i for i, s in enumerate(vocab)}
idx2sent = {i: s for s, i in sent2idx.items()}

# Input sequence (sentences)
sequence = [
    'deep learning is fun',
    'machine learning is powerful',
    'AI is the future'
]

target = [
    'machine learning is powerful',
    'AI is the future',
    '<stop>'
]

# One-hot encoding
X = np.eye(len(vocab))[[sent2idx[s] for s in sequence]].reshape(len(sequence), 1, len(vocab))
y = np.eye(len(vocab))[[sent2idx[s] for s in target]]

# Model
model = Sequential([
    SimpleRNN(16, input_shape=(1, len(vocab))),
    Dense(len(vocab), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=500, verbose=0)

# Predict next sentence
test = np.eye(len(vocab))[sent2idx['AI is the future']].reshape(1,1,len(vocab))
pred = model.predict(test)
print("Next sentence:", idx2sent[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Next sentence: <stop>

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# Vocabulary
vocab = ['deep', 'learning', 'is', 'very', 'powerful', '<stop>']
word2idx = {w:i for i,w in enumerate(vocab)}
idx2word = {i:w for w,i in word2idx.items()}

# Sequence
sequence = ['deep', 'learning', 'is', 'very']
target   = ['learning', 'is', 'very', 'powerful']

# One-hot encoding
X = np.eye(len(vocab))[[word2idx[w] for w in sequence]]
y = np.eye(len(vocab))[[word2idx[w] for w in target]]

# Reshape for LSTM → (samples, timesteps, features)
X = X.reshape(1, len(sequence), len(vocab))
y = y.reshape(1, len(target), len(vocab))

# Model
model = Sequential([
    LSTM(32, return_sequences=True, input_shape=(len(sequence), len(vocab))),
    Dense(len(vocab), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')

# Train
model.fit(X, y, epochs=300, verbose=0)

# Predict next word after sequence
pred = model.predict(X)
print("Next word:", idx2word[np.argmax(pred[0, -1])])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Next word: powerful

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense
import numpy as np

# Same vocabulary
vocab = ['deep', 'learning', 'is', 'very', 'powerful', '<stop>']
word2idx = {w:i for i,w in enumerate(vocab)}
idx2word = {i:w for w,i in word2idx.items()}

sequence = ['deep', 'learning', 'is', 'very']
target   = ['learning', 'is', 'very', 'powerful']

# One-hot encoding
X = np.eye(len(vocab))[[word2idx[w] for w in sequence]]
y = np.eye(len(vocab))[[word2idx[w] for w in target]]

X = X.reshape(1, len(sequence), len(vocab))
y = y.reshape(1, len(target), len(vocab))

# Model
model = Sequential([
    GRU(32, return_sequences=True, input_shape=(len(sequence), len(vocab))),
    Dense(len(vocab), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')

# Train
model.fit(X, y, epochs=300, verbose=0)

# Prediction
pred = model.predict(X)
print("Next word:", idx2word[np.argmax(pred[0, -1])])

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# Example vocab (toy)
input_vocab_size = 10
target_vocab_size = 10
latent_dim = 64

# Encoder
encoder_inputs = Input(shape=(None, input_vocab_size))
encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None, target_vocab_size))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

decoder_dense = Dense(target_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy')

print(model.summary())
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, None, 10)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, None, 10)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 64),      │     19,200 │ input_layer_4[0]… │
# │                     │ (None, 64),       │            │                   │
# │                     │ (None, 64)]       │            │                   │
# ...

# %%
from keras.layers import Attention

# Encoder
encoder_inputs = Input(shape=(None, input_vocab_size))
encoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)

# Decoder
decoder_inputs = Input(shape=(None, target_vocab_size))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=[state_h, state_c])

# Attention Layer
attention = Attention()
attention_output = attention([decoder_outputs, encoder_outputs])

# Combine attention + decoder output
from keras.layers import Concatenate
decoder_combined = Concatenate(axis=-1)([decoder_outputs, attention_output])

# Final Dense
decoder_dense = Dense(target_vocab_size, activation='softmax')
final_output = decoder_dense(decoder_combined)

# Model
model = Model([encoder_inputs, decoder_inputs], final_output)

model.compile(optimizer='adam', loss='categorical_crossentropy')

print(model.summary())
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, None, 10)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_7       │ (None, None, 10)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │     19,200 │ input_layer_6[0]… │
# │                     │ 64), (None, 64),  │            │                   │
# │                     │ (None, 64)]       │            │                   │
# ...
